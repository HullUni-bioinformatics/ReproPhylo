# %% [markdown]
# Plot out sequence length and %GC charts
# =======
# I'm using a script from BioPython http://biopython.org/DIST/docs/tutorial/Tutorial.html#htoc233
# BioPython needs to be installed first
#
# This works with genbank files too

# %% [markdown]
# ## Plotting sequence lengths

# %%
from Bio import SeqIO
sizes = [len(rec) for rec in SeqIO.parse("data/brachionus2k_misc.fasta", "fasta")]
hist(sizes, bins=50)
title("%i Brachionus sequences\nLengths %i to %i" % (len(sizes), min(sizes), max(sizes))) 
xlabel("Sequence length (bp)")
ylabel("Count") 
show()

# %% [markdown]
# ## Plotting %GC of sequences

# %%
#this from BioPython tutorial
from Bio import SeqIO
from Bio.SeqUtils import GC

gc_values = sorted(GC(rec.seq) for rec in SeqIO.parse("data/brachionus2k_misc.fasta", "fasta"))
#print gc_values
#this put together by me
hist(gc_values, bins=40, color='green')
title("Percentage GC for %i Brachionus rotifer sequences,\n mean %0.1f%%,\n range %0.1f to %0.1f%%" % (len(gc_values), mean(gc_values), min(gc_values), max(gc_values)))
xlabel("GC%")
ylabel("Number of Sequences") 
show()

# %% [markdown]
# ### Finale

# %% [markdown]
# Here is everything together, producing two graphs

# %%
#this modified from BioPython tutorial
from Bio import SeqIO 
sizes = [len(rec) for rec in SeqIO.parse("data/brachionus2k_misc.fasta", "fasta")]

#not specifying color also gives blue
hist(sizes, bins=40, color='blue')
title("Lengths of %i Brachionus rotifer sequences\n Mean %i bp, range %i - %i bp" % (len(sizes), mean(sizes), min(sizes), max(sizes))) 
xlabel("Sequence length (bp)")
ylabel("Count") 
show()

#this from BioPython tutorial
from Bio import SeqIO
from Bio.SeqUtils import GC

gc_values = sorted(GC(rec.seq) for rec in SeqIO.parse("data/brachionus2k_misc.fasta", "fasta"))

#this put together by me
hist(gc_values, bins=40, color='green')
title("Percentage GC for %i Brachionus rotifer sequences\n Mean %0.1f%%, range %0.1f - %0.1f%%" % (len(gc_values), mean(gc_values), min(gc_values), max(gc_values)))
xlabel("Percentage GC")
ylabel("Count") 
show()

# %% [markdown]
# Try to extract range of sequences, ie ask user to enter size range to exclude/include or GC range to keep

# %%
# Extract a subset of sequences as follows

# Set the range of GC values to extract
gc_subset = [val for val in gc_values if val >= 35 and val <= 40]

# Plot a histogram of extracted %GC range
hist(gc_subset, bins=40, color='green')
title("Percentage GC for %i Brachionus rotifer sequences\n Mean %0.1f%%, range %0.1f - %0.1f%%" % (len(gc_values), mean(gc_values), min(gc_values), max(gc_values)))
xlabel("Percentage GC")
ylabel("Count") 
show()

# Set the range length values to extract
len_subset = [val for val in sizes if val >= 500 and val <= 900]
#print len_subset

# Plot a histogram of extracted length range
hist(len_subset, bins=40, color='blue')
title("Lengths of %i Brachionus rotifer sequences\n Mean %i bp, range %i - %i bp" % (len(len_subset), mean(len_subset), min(len_subset), max(len_subset))) 
xlabel("Sequence length (bp)")
ylabel("Count") 
show()

# %% [markdown]
# Try again with different way

# %%
# Extract a subset of sequences as follows

# set the minimum and maximum permissable gc%
min_gc = 35
max_gc = 50

# Set the range of GC values to extract
gc_subset = [val for val in gc_values if val >= min_gc and val <= max_gc]

#print the number of values we are plotting in %GC subset defined by min and max above
print("Out of " + str(len(gc_values)) + " total records " + str(len(gc_subset)) + " are in the range " + str(min_gc) + "% - " + str(max_gc) + "% GC")

# Plot a histogram of extracted %GC range
hist(gc_subset, bins=40, color='green')
title("Percentage GC for %i Brachionus rotifer sequences\n Mean %0.1f%%, range %0.1f - %0.1f%%" % (len(gc_subset), mean(gc_subset), min(gc_subset), max(gc_subset)))
xlabel("Percentage GC")
ylabel("Count") 
show()

# set the minimum and maximum permissable sizes in bp
min_size = 500
max_size = 900

# Set the range length values to extract
len_subset = [val for val in sizes if val >= min_size and val <= max_size]

#print the number of values we are plotting in length subset defined by min and max above
print("Out of " + str(len(sizes)) + " total records " + str(len(len_subset)) + " are in the range " + str(min_size) + "bp - " + str(max_size) + "bp")

# Plot a histogram of extracted length range
hist(len_subset, bins=40, color='blue')
title("Lengths of %i Brachionus rotifer sequences\n Mean %i bp, range %i - %i bp" % (len(len_subset), mean(len_subset), min(len_subset), max(len_subset))) 
xlabel("Sequence length (bp)")
ylabel("Count") 
show()
# Out:
# Out of 2738 total records 1673 are in the range 35% - 50% GC
# Out of 2738 total records 1912 are in the range 500bp - 900bp
