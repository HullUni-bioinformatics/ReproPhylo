# %% [markdown]
# Plot out sequence length graphs
# =======
# I'm using a script from BioPython http://biopython.org/DIST/docs/tutorial/Tutorial.html#htoc233
# I need to make sure that I have BioPython installed first though!
# pylab is a part of matplotlib which is a nightmare to install on OSX
#
# SPM: You shouldn't need to 'import pylab' if you run IPython notebook with pylab inline.
#
# SPM: On OSX I advocate using homebrew to install everything. It is awesome!

# %%
from Bio import SeqIO
sizes = [len(rec) for rec in SeqIO.parse("data/22_rotifer_COI_seqs.fas", "fasta")]
hist(sizes, bins=40)
title("%i Brachionus sequences\nLengths %i to %i" % (len(sizes),min(sizes),max(sizes))) 
xlabel("Sequence length (bp)")
ylabel("Count") 
show()

# %%
from Bio import SeqIO
from Bio.SeqUtils import GC

gc_values = sorted(GC(rec.seq) for rec in SeqIO.parse("data/22_rotifer_COI_seqs.fas", "fasta"))

plot(gc_values)
title("%i brachionus\nGC%% %0.1f to %0.1f" % (len(gc_values),min(gc_values),max(gc_values)))
xlabel("Genes")
ylabel("GC%")
show()

# %% [markdown]
# I don't really understand this graph!

# %%
#this from BioPython tutorial
from Bio import SeqIO
from Bio.SeqUtils import GC

gc_values = sorted(GC(rec.seq) for rec in SeqIO.parse("data/22_rotifer_COI_seqs.fas", "fasta"))

#this put together by me
hist(gc_values, bins=40)
title("percentage GC for %i Brachionus rotifer sequences,\n mean %0.1f%%,\n range %0.1f to %0.1f%%" % (len(gc_values),mean(gc_values),min(gc_values),max(gc_values)))
xlabel("GC%")
ylabel("Genes") 
show()

# %% [markdown]
# ### Finale

# %% [markdown]
# Here is everything together, producing two graphs

# %%
#this modified from BioPython tutorial
from Bio import SeqIO 
sizes = [len(rec) for rec in SeqIO.parse("data/22_rotifer_COI_seqs.fas", "fasta")]

#not specifying color also gives blue
hist(sizes, bins=40, color='blue')
title("Lengths of %i Brachionus rotifer sequences\n Mean %i bp, range %i - %i bp" % (len(sizes),mean(sizes),min(sizes),max(sizes))) 
xlabel("Sequence length (bp)")
ylabel("Count") 
show()

#this from BioPython tutorial
from Bio import SeqIO
from Bio.SeqUtils import GC

gc_values = sorted(GC(rec.seq) for rec in SeqIO.parse("data/22_rotifer_COI_seqs.fas", "fasta"))

#this put together by me
hist(gc_values, bins=40, color='green')
title("Percentage GC for %i Brachionus rotifer sequences\n Mean %0.1f%%, range %0.1f - %0.1f%%" % (len(gc_values),mean(gc_values),min(gc_values),max(gc_values)))
xlabel("Percentage GC")
ylabel("Count") 
show()

# %% [markdown]
# I wonder if it is possible to extract range of sequences, ie ask user to enter size range to exclude/include or GC range to keep?
