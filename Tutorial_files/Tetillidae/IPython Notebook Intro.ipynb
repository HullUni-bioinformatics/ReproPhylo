# %% [markdown]
# ## This is a <font color=red>text cell</font> with instructions.
# Run the cell bellow to load reprophylo by clicking it and then **`shift+enter`**

# %%
from reprophylo import *

# %% [markdown]
# Running the next cell in the same way will load an existing `Project` from a file:

# %%
project = unpickle_pj('tetillidae_tutorial')

# %% [markdown]
# The next cell will calculate sequence statistics for the records in the project and will show them inline:

# %%
# %matplotlib inline

project.report_seq_stats()
# Out:
# Distribution Of Sequence Lengths
# Distribution Of Sequence Statistic "Gc_Content"
# Distribution Of Sequence Statistic "Nuc_Degen_Prop"
# Distribution Of Sequence Statistic "Prot_Degen_Prop"
